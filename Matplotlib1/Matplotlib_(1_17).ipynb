# %%
import matplotlib

matplotlib.__version__
# Out:
# '3.7.1'

# %% [markdown]
# 01.Matplotlib 기본 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
#plot() 안의 리스트 값은 y값
#x값은 [0,1,2,3]이 default
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
#리스트 하나만 넣으면 y값 으로 인식 / 두개 넣으면 x,y 순
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# 세번째 인자로 선의 색상과 형태를 지정하믄 포맷 문자열 입력 가능
#'ro'는 red + o '
plt.axis([0, 6, 0, 20]) # [xmin, xmax, ymin, ymax]를 지정
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# 2. Matplotlib 숫자 입력

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10]) # defualt 값은 꺾은선 그래프 (각각으 지점들을 직선으로 잇)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.show()

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]} #딕셔너리 사용 가능

plt.plot('data_x', 'data_y', data=data_dict) #key 값으로 불러주기
plt.show()

# %% [markdown]
# 03. Matplotlib 축 레이블 설정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %%
# 여백 지정
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15) # 15pt 여백
plt.ylabel('Y-Axis', labelpad=20) # 20pt 여백
plt.show()

# %%
# 폰트 스타일 설정
import matplotlib.pyplot as plt

font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %%
# 위치 지정
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc='right') # loc 이 location의 준말이란걸 지금 깨달아버림 ;; #({‘left’, ‘center’, ‘right’})
plt.ylabel('Y-Axis', loc='top') # ({‘bottom’, ‘center’, ‘top’})
plt.show()

# %% [markdown]
# 4. Matplotlib 범례 표시하기

# %%
# 범례(Legend)는 그래프에 데이터의 종류 표시하기 위한 텍스트
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)') #label 을 지정하고
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend() #여기서 legend 함수를 호출해줘야함
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc=(0.0, 0.0)) #왼쪽 아래
plt.legend(loc=(0.5, 0.5)) #중앙
#plt.legend(loc=(1.0, 1.0)) #오른쪽 위

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right') # 문자열로도 지정가능

plt.show()

# %%
# 열 개수 지정
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2)    # ncol = 2 #열개수를 지정 즉 표에서 컬럼의 개수로 생각
# best 는 자동으로 최적의 위치 선택해
plt.show()

# %%
#폰트 크기 지정
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14) #fontsize로 인자 받음

plt.show()

# %%
#텍스트 상자 테두리 바꾸기
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True) #테두리 표시 여부 shadow로 표시

plt.show()

# %% [markdown]
# 05.Matplotlib 축 범위 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax] #x만 지정하려면 xlim
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
# 입력값 없으면 데이터에 맞게 자동 설
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square')
plt.axis('scaled')

plt.show()
# square : xmax-xmin = ymax=ymin
# scaled : xy축 눈금간격이 같음

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim() #xlim(), ylim() 함수는 그래프 영역에 표시되는 X축, Y축의 범위를 각각 반환
print(x_range, y_range)

axis_range = plt.axis('scaled') #axis() 함수는 그래프 영역에 표시되는 X, Y축의 범위를 반환
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %%
import matplotlib.pyplot as plt
#‘ - ‘ (Solid), ‘ - - ‘ (Dashed), ‘ : ‘ (Dotted), ‘ -. ‘ (Dash-dot)
plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0]) #양쪽끝값
plt.legend(loc='upper right', ncol=4)
plt.show()

# %%
import matplotlib.pyplot as plt
'''(0, (1, 1))은 ‘dotted’와 같고, (0, (5, 5))는 ‘dashed’와 같습니다.

또한 (0, (3, 5, 1, 5))는 ‘dashdotted’'''
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ![화면 캡처 2024-09-23 121417.png](data:image/png;base64,...)

# %% [markdown]
# 7.Matplotlib 마커 지정

# %%
import matplotlib.plt

#'bo-'의 구성 : blue + circle + solid line
#'bo--'의 구성 : blue + circle + dashed line
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ![colors linestyles markers.png](data:image/png;base64,...)

# %%
# 선/마커 표시 형식

# %%
#marker 파라미터 사용하기
import matplotlib.pyplot as plt

plt.plot([4, 5, 6], marker="H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')
plt.show()

# %% [markdown]
# ![set_marker_10.png](data:image/png;base64,...)

# %% [markdown]
# 8. Matplotlib 색상 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %%
# Hex code 사용하기 (color를 code로 나타낸 것)
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# 9. Matplotlib 그래프 영역 채우기
# - fill_between() - 두 수평 방향의 곡선 사이를 채웁니다.
# - fill_betweenx() - 두 수직 방향의 곡선 사이를 채웁니다.
# - fill() - 다각형 영역을 채웁니다.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5) #x좌표 1이 아니라 위에 원소 몇번째에 대응 시킬지를 보는것

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#fill_betweenx 함수
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

plt.show()

# %%
# 두 그래프 사이 영역 채우기
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
# 다각형 영역 채우기
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.fill 함수
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# 10. Matplotlib 축 스케일 지정하기

# %%
#x축 스케일 지정하기
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
#numpy 라이브러리에서 제공하는 함수로, 지정된 범위에서 균등한 간격으로 숫자 배열을 생성
#-10에서 10까지 100개의 값으로 나눈 배열 생
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog')
#symlog = Symmetrical Log Scale : 양음 방향이 대칭적인 로그 스케일로 표시 가능

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100)
y = np.exp(x) #e의 x승

plt.plot(x, y)
plt.yscale('linear')
# plt.yscale('log')

plt.show()

# %% [markdown]
# 11. Matplotlib 여러 곡선 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.') #한번에 선언 가능
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# 12. Matplotlib 그리드 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) #그리드는 격자무늬

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y')
#{‘both’, ‘x’, ‘y’} 중 선택할 수 있고 디폴트는 ‘both'

plt.show()

# %%
#그리드 선 스타일 설정
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

plt.show()

# %% [markdown]
# 13. Matplotlib 눈금 표시하기
# - 틱 (Tick)은 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
# - matplotlib.pyplot 모듈의 xticks(), yticks(), tick_params() 함수를 이용

# %%
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# 눈금 레이블 작성
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
#공란도 설정 가능
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# - tick_params() 함수를 사용하면 눈금의 스타일을 다양하게 설정.
#
# - axis는 설정이 적용될 축을 지정. {‘x’, ‘y’, ‘both’} 중 선택
#
# - direction을 ‘in’, ‘out’으로 설정하면 눈금이 안/밖으로 표시. {‘in’, ‘out’, ‘inout’} 중 선택 가능
#
# - length는 눈금의 길이를 지정
#
# - pad는 눈금과 레이블과의 거리를 지정
#
# - labelsize는 레이블의 크기를 지정
#
# - labelcolor는 레이블의 색상을 지정
#
# - top/bottom/left/right를 True/False로 지정하면 눈금이 표시될 위치를 선택 가능
#
# - width는 눈금의 너비를 지정
#
# - color는 눈금의 색상을 지정

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')

plt.show()

# %% [markdown]
# 14. Matplotlib 타이틀 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)
#{‘left’, ‘center’, ‘right’} 중 선택 / 디폴트는 'center'
# pad 파라미터는 타이틀과 그래프간 간격을 포인트로 설정
plt.show()

# %% [markdown]
# fontdict 파라미터에 딕셔너리 형태로 폰트 스타일을 설정할 수 있습니다.
#
# ‘fontsize’를 16으로, ‘fontweight’를 ‘bold’로 설정했습니다.
#
# ‘fontsize’는 포인트 단위의 숫자를 입력하거나 ‘smaller’, ‘x-large’ 등의 상대적인 설정을 할 수 있습니다.
#
# ‘fontweight’에는 {‘normal’, ‘bold’, ‘heavy’, ‘light’, ‘ultrabold’, ‘ultralight’}와 같이 설정할 수 있습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position()) #타이틀 위치 출력
print(title_left.get_text()) #타이틀 텍스트 출력

print(title_right.get_position())
print(title_right.get_text())

plt.show()
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title

# %% [markdown]
# 15. Matplotlib 수평선 / 수직선 표시하기
# - axhline(): 축을 따라 수평선을 표시합니다.
# - axvline(): 축을 따라 수직선을 표시합니다.
# - hlines(): 지정한 점을 따라 수평선을 표시합니다.
# - vlines(): 지정한 점을 따라 수직선을 표시합니다.

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)
plt.hlines(-0.62, 1.0, 2.5, color='gray', linestyle='solid', linewidth=3)

plt.show()

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axvline(1.0, 0.2, 0.8, color='lightgray', linestyle='--', linewidth=2)
plt.vlines(1.8, -3.0, 2.0, color='gray', linestyle='solid', linewidth=3)

plt.show()

# %% [markdown]
# 16. Matplotlib 막대 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)

plt.show()

# %%
# 색상 지정하기
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, color='y')
# plt.bar(x, values, color='dodgerblue')
# plt.bar(x, values, color='C2')
# plt.bar(x, values, color='#e35f62')
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.bar(x, values, color=colors)
plt.xticks(x, years)

plt.show()

# %%
# 막대 폭 지정
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, width=0.4)
# plt.bar(x, values, width=0.6)
# plt.bar(x, values, width=0.8)
# plt.bar(x, values, width=1.0)
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, align='edge', edgecolor='lightgray',
        linewidth=5, tick_label=years)

plt.show()

# %% [markdown]
# 17. Matplotlib 수평 막대 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np
# y축 기준 막대그래프 그리기
#plt.barh()
y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values)
plt.yticks(y, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, color='y')
# plt.barh(y, values, color='dodgerblue')
# plt.barh(y, values, color='C2')
# plt.barh(y, values, color='#e35f62')
plt.yticks(y, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']
# 리스트 순서대로 아래부터 적용
plt.barh(y, values, color=colors)
plt.yticks(y, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, height=0.4) #width 의 개념
# plt.barh(y, values, height=0.6)
# plt.barh(y, values, height=0.8) #default 값
# plt.barh(y, values, height=1.0)
plt.yticks(y, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, align='edge', edgecolor='#eee',
         linewidth=5, tick_label=years)

plt.show()
