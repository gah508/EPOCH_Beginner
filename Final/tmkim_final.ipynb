# %% [markdown]
# # **🌱 EPOCH 비기너 세션 Final Test 🔥**

# %% [markdown]
# ---

# %% [markdown]
# ## **1️⃣ 'Sleep_health_and_lifestyle_dataset.csv' 파일을 불러와 수면 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# CSV 파일 불러오기
sleep_data = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
sleep_data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %% [markdown]
# ### (1) 성별에 따른 평균 수면 시간('Sleep Duration')을 출력하세요.

# %%
sleep_data.groupby('Gender')['Sleep Duration'].mean()
# Out:
# Gender
# Female    7.229730
# Male      7.036508
# Name: Sleep Duration, dtype: float64

# %% [markdown]
# ### (2) 스트레스 수준('Stress Level')이 3 이상인 사람들의 수면 질('Quality of Sleep') 평균을 구하세요.

# %%
sleep_data.query("`Stress Level` >= 3")['Quality of Sleep'].mean()
# Out:
# 7.31283422459893

# %% [markdown]
# ### (3) 아래와 같은 수면 데이터에 대한 네 가지 그래프를 그리세요.
# * colors = ['gold', 'gray','darkgray', 'silver', 'lightgray', 'whitesmoke'] & 'coral' & 'purple' & 'green'
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

# 데이터 및 색상 설정
colors = ['gold', 'gray', 'darkgray', 'silver', 'lightgray', 'whitesmoke']
highlight_colors = ['coral', 'purple', 'green']
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# 1. Distribution of Quality of Sleep (파이 차트)
quality_counts = sleep_data['Quality of Sleep'].value_counts()
axs[0, 0].pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', colors=colors)
axs[0, 0].set_title('Distribution of Quality of Sleep')

# 2. Average Sleep Duration by Age (막대 그래프)
avg_sleep_by_age = sleep_data.groupby('Age')['Sleep Duration'].mean()
axs[0, 1].bar(avg_sleep_by_age.index, avg_sleep_by_age.values, color='coral')
axs[0, 1].set_title('Average Sleep Duration by Age')
axs[0, 1].set_xlabel('Age')
axs[0, 1].set_ylabel('Sleep Duration (Hours)')

# 3. Counts of Quality of Sleep Ratings (막대 그래프)
axs[1, 0].bar(, quality_counts, color='coral')
axs[1, 0].set_title('Counts of Quality of Sleep Ratings')
axs[1, 0].set_xlabel('Quality of Sleep')
axs[1, 0].set_ylabel('Count')

# 4. Quality of Sleep Trend by Age (선 그래프)
axs[1, 1].plot(sleep_data['Age'], sleep_data['Quality of Sleep'], marker='o', linestyle='-', color='green')
axs[1, 1].set_title('Quality of Sleep Trend by Age')
axs[1, 1].set_xlabel('Age')
axs[1, 1].set_ylabel('Quality of Sleep')


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e04617c0024c> in <cell line: 23>()
#      21
#      22 # 3. Counts of Quality of Sleep Ratings (막대 그래프)
# ---> 23 axs[1, 0].bar(sleep_data['Quality of Sleep'], quality_counts, color='coral')
#      24 axs[1, 0].set_title('Counts of Quality of Sleep Ratings')
#      25 axs[1, 0].set_xlabel('Quality of Sleep')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...

# %% [markdown]
# ## **2️⃣‘calendar.csv' 파일과 'listings.csv' 파일을 불러와 Airbnb 예약 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
# CSV 파일 불러오기
calendar_data = pd.read_csv('calendar.csv')
listing_data = pd.read_csv('listings.csv')
calendar_data.head()
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0        6606  2024-06-24         f  $90.00             NaN            30.0
# 1        6606  2024-06-25         f  $90.00             NaN            30.0
# 2        6606  2024-06-26         f  $90.00             NaN            30.0
# 3        6606  2024-06-27         f  $90.00             NaN            30.0
# 4        6606  2024-06-28         f  $90.00             NaN            30.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
listing_data.head()
# Out:
#    listing_id                                        name host_id  host_name  \
# 0      6606.0         Fab, private seattle urban cottage!   14942      Joyce
# 1      9419.0         Glorious sun room w/ memory foambed   30559  Angielena
# 2      9531.0         The Adorable Sweet Orange Craftsman   31481     Cassie
# 3      9534.0            The Coolest Tangerine Dream MIL!   31481     Cassie
# 4      9596.0  the down home , spacious, central and fab!   14942      Joyce
#
#          room_type price  minimum_nights number_of_reviews  \
# 0  Entire home/apt    99              30               160
# 1     Private room    76               2               196
# 2  Entire home/apt   189               3                97
# 3  Entire home/apt   125               2                77
# 4  Entire home/apt   NaN              30                96
#
#    calculated_host_listings_count  availability_365 number_of_reviews_ltm  \
# ...

# %% [markdown]
# ### (1) 두 데이터셋을 'listing_id'를 기준으로 병합하여 숙소가 예약이 가능한 상태인 날짜의 수를 세어 숙소별로 출력하세요.
# * Hint: 'availability_365'가 0보다 크면 예약 가능한 상태
