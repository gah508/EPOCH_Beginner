# %% [markdown]
# # **🌱 EPOCH 비기너 세션 Final Test 🔥**

# %% [markdown]
# ---

# %% [markdown]
# ## **1️⃣ 'Sleep_health_and_lifestyle_dataset.csv' 파일을 불러와 수면 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

sleep = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sleep_health_and_lifestyle_dataset.csv')
sleep = pd.DataFrame(sleep)
sleep
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ### (1) 성별에 따른 평균 수면 시간('Sleep Duration')을 출력하세요.

# %%
SD = sleep.groupby('Gender')[['Sleep Duration']].mean().reset_index()
SD
# Out:
#    Gender  Sleep Duration
# 0  Female        7.229730
# 1    Male        7.036508

# %% [markdown]
# ### (2) 스트레스 수준('Stress Level')이 3 이상인 사람들의 수면 질('Quality of Sleep') 평균을 구하세요.

# %%
QS = sleep[sleep['Stress Level'] >= 3].groupby('Stress Level')[['Sleep Duration']].mean().reset_index()
QS
# Out:
#    Stress Level  Sleep Duration
# 0             3        8.226761
# 1             4        7.030000
# 2             5        7.483582
# 3             6        7.454348
# 4             7        6.468000
# 5             8        6.050000

# %% [markdown]
# ### (3) 아래와 같은 수면 데이터에 대한 네 가지 그래프를 그리세요.
# * colors = ['gold', 'gray','darkgray', 'silver', 'lightgray', 'whitesmoke'] & 'coral' & 'purple' & 'green'
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].pie(ratio, label, autopct='%.1f%%')
ax[0][1].plt.bar
ax[1][0].
ax[1][1].
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6a6fc53b0d41> in <cell line: 4>()
#       2
#       3 fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
# ----> 4 ax[0][0].pie('Quality of Sleep', autopct='%.1f%%')      # left-top plt.pie(ratio, labels=labels, autopct='%.1f%%')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %% [markdown]
# ## **2️⃣‘calendar.csv' 파일과 'listings.csv' 파일을 불러와 Airbnb 예약 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
calendar = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/calendar.csv')
calendar = pd.DataFrame(calendar)
calendar
# Out:
#          listing_id        date available   price  adjusted_price  \
# 0              6606  2024-06-24         f  $90.00             NaN
# 1              6606  2024-06-25         f  $90.00             NaN
# 2              6606  2024-06-26         f  $90.00             NaN
# 3              6606  2024-06-27         f  $90.00             NaN
# 4              6606  2024-06-28         f  $90.00             NaN
# ...             ...         ...       ...     ...             ...
# 2350873      708774  2025-06-19         t  $85.00             NaN
# 2350874      708774  2025-06-20         t  $85.00             NaN
# 2350875      708774  2025-06-21         t  $85.00             NaN
# 2350876      708774  2025-06-22         t  $85.00             NaN
# 2350877      708774  2025-06-23         t  $85.00             NaN
#
#          minimum_nights  maximum_nights
# 0                  30.0          1125.0
# 1                  30.0          1125.0
# 2                  30.0          1125.0
# ...

# %%
listings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/listings.csv')
listings = pd.DataFrame(listings)
listings
# Out:
#         listing_id                                              name  \
# 0     6.606000e+03               Fab, private seattle urban cottage!
# 1     9.419000e+03               Glorious sun room w/ memory foambed
# 2     9.531000e+03               The Adorable Sweet Orange Craftsman
# 3     9.534000e+03                  The Coolest Tangerine Dream MIL!
# 4     9.596000e+03        the down home , spacious, central and fab!
# ...            ...                                               ...
# 6431  1.180000e+18   Ballard Vintage: Prime location | Newly updated
# 6432  1.180000e+18                 Near UW&Seattle children Hospital
# 6433  1.180000e+18                                The Lavender House
# 6434  1.180000e+18                     King bed near lake Washington
# 6435  1.190000e+18  Luxurious 2BR Penthouse with Water View Seattle!
#
#         host_id         host_name        room_type price  minimum_nights  \
# ...

# %% [markdown]
# ### (1) 두 데이터셋을 'listing_id'를 기준으로 병합하여 숙소가 예약이 가능한 상태인 날짜의 수를 세어 숙소별로 출력하세요.
# * Hint: 'availability_365'가 0보다 크면 예약 가능한 상태

# %%
merged_data = pd.merge(left=calendar, right=listings, on='listing_id')
merged_data
# Out:
#          listing_id        date available price_x  adjusted_price  \
# 0              6606  2024-06-24         f  $90.00             NaN
# 1              6606  2024-06-25         f  $90.00             NaN
# 2              6606  2024-06-26         f  $90.00             NaN
# 3              6606  2024-06-27         f  $90.00             NaN
# 4              6606  2024-06-28         f  $90.00             NaN
# ...             ...         ...       ...     ...             ...
# 1088061      708774  2025-06-19         t  $85.00             NaN
# 1088062      708774  2025-06-20         t  $85.00             NaN
# 1088063      708774  2025-06-21         t  $85.00             NaN
# 1088064      708774  2025-06-22         t  $85.00             NaN
# 1088065      708774  2025-06-23         t  $85.00             NaN
#
#          minimum_nights_x  maximum_nights  \
# 0                    30.0          1125.0
# 1                    30.0          1125.0
# 2                    30.0          1125.0
# ...

# %%
available = merged_data.query('available == "t"')
available
# Out:
#          listing_id        date available price_x  adjusted_price  \
# 33             6606  2024-07-27         t  $90.00             NaN
# 34             6606  2024-07-28         t  $90.00             NaN
# 35             6606  2024-07-29         t  $90.00             NaN
# 36             6606  2024-07-30         t  $90.00             NaN
# 37             6606  2024-07-31         t  $90.00             NaN
# ...             ...         ...       ...     ...             ...
# 1088061      708774  2025-06-19         t  $85.00             NaN
# 1088062      708774  2025-06-20         t  $85.00             NaN
# 1088063      708774  2025-06-21         t  $85.00             NaN
# 1088064      708774  2025-06-22         t  $85.00             NaN
# 1088065      708774  2025-06-23         t  $85.00             NaN
#
#          minimum_nights_x  maximum_nights  \
# 33                   30.0          1125.0
# 34                   30.0          1125.0
# 35                   30.0          1125.0
# ...

# %%
available.groupby('name')['date'].size().reset_index(name='available_dates_count')
# Out:
#                                                    name  available_dates_count
# 0       "B House" Modern West Seattle Townhome 2br/2bth                     45
# 1                                   "Captains Quarters"                    104
# 2     "Hellebore House" -- in the heart of Phinney R...                     58
# 3       "TRANQUiL TERRACe" A/C, Couch, Desk/TV & TREEs!                     11
# 4                   "The 5-Star House"  #9 The red room                     43
# ...                                                 ...                    ...
# 2820   ~Vibrant Lake View Seattle Apartment w/ Balcony~                    223
# 2821   狩?3 Master Bedrooms | Contemporary 3 Story House                    150
# 2822  狩?Rooftop Views of the Space Needle, Sound, & ...                     54
# 2823                              疫뽪솺?뺞댛?븀쭫竊?竊?28763024                    280
# 2824    西멘쪓西듀ㅎ西쀠ㄴ  ?몄떎?꾩쐞 Prince room (Close to Amazon)                    318
#
# [2825 rows x 2 columns]
